# %% [markdown]
# ![Project 3 Flowchart.png](<Project 3 Flowchart.png>)

# %%
data = [
    ["Evelyn", 17, 5.5, 80, "F"],
    ["Jessica", 16, 6.0, 85, "F"],
    ["Somto", 17, 5.4, 70, "F"],
    ["Edith", 18, 5.9, 60, "F"],
    ["Liza", 16, 5.6, 76, "F"],
    ["Madonna", 18, 5.5, 66, "F"],
    ["Waje", 17, 6.1, 87, "F"],
    ["Tola", 20, 6.0, 95, "F"],
    ["Aisha", 19, 5.7, 50, "F"],
    ["Latifa", 17, 5.5, 49, "F"],
    ["Chinedu", 19, 5.7, 74, "M"],
    ["Liam", 16, 5.9, 87, "M"],
    ["Wale", 18, 5.8, 75, "M"],
    ["Gbenga", 17, 6.1, 68, "M"],
    ["Abiola", 20, 5.9, 66, "M"],
    ["Kola", 19, 5.5, 78, "M"],
    ["Kunle", 16, 6.1, 87, "M"],
    ["George", 18, 5.4, 98, "M"],
    ["Thomas", 17, 5.8, 54, "M"],
    ["Wesley", 19, 5.7, 60, "M"]
]
print(f"{'Name':^10} {'Age':^5} {'Height':^7} {'Score':^6} {'Gender':^5}")

for row in data:
    print(f"{row[0]:^10} {row[1]:^5} {row[2]:^7} {row[3]:^6} {row[4]:^5}")
# Out:
#    Name     Age  Height  Score  Gender
#   Evelyn    17     5.5     80     F
#  Jessica    16     6.0     85     F
#   Somto     17     5.4     70     F
#   Edith     18     5.9     60     F
#    Liza     16     5.6     76     F
#  Madonna    18     5.5     66     F
#    Waje     17     6.1     87     F
#    Tola     20     6.0     95     F
#   Aisha     19     5.7     50     F
#   Latifa    17     5.5     49     F
#  Chinedu    19     5.7     74     M
#    Liam     16     5.9     87     M
#    Wale     18     5.8     75     M
#   Gbenga    17     6.1     68     M
#   Abiola    20     5.9     66     M
#    Kola     19     5.5     78     M
#   Kunle     16     6.1     87     M
#   George    18     5.4     98     M
#   Thomas    17     5.8     54     M
#   Wesley    19     5.7     60     M

# %% [markdown]
# Project 1A Pseudocode
# ```
# START
#
# Customer proceeds to store exit
#
# Customer shows receipt to store attendant
#
# IF receipt is valid THEN
#     PRINT "Thank you for shopping with us"
#     Allow customer to leave store
# ELSE
#     Send customer back to cashier for verification
# END IF
#
# END
# ```

# %% [markdown]
# Project 1A Flowchart
#
# ![Project 1A FlowChart.png](<Project 1A FlowChart.png>)

# %% [markdown]
# Project 1B Flowchart
#
# ![Project 1B Flowchart.png](<Project 1B Flowchart.png>)

# %% [markdown]
# Project 1C
# ```
# START
# INPUT name1
# INPUT name2
# INPUT age1
# INPUT age2
# SET temp to age1
# SET age1 to age2
# SET age2 to temp
# PRINT name1, age2
# PRINT name2, age1
# END
# ```

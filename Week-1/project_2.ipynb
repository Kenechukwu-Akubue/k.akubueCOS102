# %% [markdown]
# ![Project 2 Flowchart.png](<Project 2 Flowchart.png>)

# %%
def flt_check(prompt):
    try:
        value = float(input(prompt))
        return value
    except ValueError:
        print("Invalid input. Please enter a number.")
        return flt_check(prompt)

P = flt_check("Enter the principal amount: #")
r = flt_check("Enter the rate of annual interest (in %): ")
R = r/100
T = flt_check("Enter the time in years: ")
N = flt_check("Enter the number of times interest is compounded per year: ")
A = P * (1 + R / N) ** (N * T)
print(f"A principal amount of ₦{P:.2f} at an annual interest rate of {r:.2f}%")
print(f"The amount after {T} years is, if the interest is compounded {N} times a year: ₦{A:.2f}")
# Out:
# A principal amount of ₦20000.00 at an annual interest rate of 0.05%
# The amount after 2.0 years is, if the interest is compounded 4.0 times a year: ₦22089.72
